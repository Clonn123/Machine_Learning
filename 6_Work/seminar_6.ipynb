# %%
# Импорт модулей
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import plotly.express as px

from scipy.stats import pearsonr
from scipy.stats import spearmanr
from scipy.stats import kendalltau
from scipy import stats
from scipy.spatial.distance import euclidean
from fastdtw import fastdtw
from itertools import combinations
from dtw import *
from scipy.signal import welch
import statsmodels.api as sm

# %%
# Загрузка данных
data1 = pd.read_csv('b30hz10.txt', sep = "\t", header = None)
data2 = pd.read_csv('h30hz10.txt', sep = "\t", header = None)

data1.rename(columns = {0: "s1", 1: "s2", 2: "s3", 3: "s4"}, inplace = True)
data1.drop(columns = [4], inplace = True)

data2.rename(columns = {0: "s1", 1: "s2", 2: "s3", 3: "s4"}, inplace = True)
data2.drop(columns = [4], inplace = True)

# data1.head()
# data2.head()

# %% [markdown]
# Задание
# ----
# ![Alt text](Task.jpg)

# %% [markdown]
# Выбор промежутка
# ---

# %%
startInd = 0
endInd = 400

data1 = data1[startInd:endInd]
data2 = data2[startInd:endInd]

data1.plot()
data2.plot()
# Out:
# <Axes: >

# %% [markdown]
# Корелляция сингналов из набора Data1
# ---

# %%
# Корреляция Спирмена
corr_spearman = data1.corr(method="spearman")
sb.heatmap(corr_spearman, annot=True, cmap='Reds')
plt.title("Data1, Spearman")
plt.show()

# Корреляция Пирсона
corr_pearson = data1.corr(method="pearson")
sb.heatmap(corr_pearson, annot=True, cmap='Reds')
plt.title("Data1, Pearson")
plt.show()

# Корреляция Кендалла
corr_kendall = data1.corr(method="kendall")
sb.heatmap(corr_kendall, annot=True, cmap='Reds')
plt.title("Data1, Kendall")
plt.show()

# %% [markdown]
# Корелляция между сигналами наборов Data1 и Data2
# ---

# %%
# Корреляция Пирсона
pearson_corr = data1.corrwith(data2, method='pearson')

# Корреляция Спирмена
spearman_corr = data1.corrwith(data2, method='spearman')

# Корреляция Кендалла
kendall_corr = data1.corrwith(data2, method='kendall')

# Визуализируйте результаты
plt.figure(figsize=(12, 4))
plt.subplot(131)
sb.heatmap(pearson_corr.values.reshape(1, -1), annot=True, cmap='Reds')
plt.title('Pearson Correlation')
plt.subplot(132)
sb.heatmap(spearman_corr.values.reshape(1, -1), annot=True, cmap='Reds')
plt.title('Spearman Correlation')
plt.subplot(133)
sb.heatmap(kendall_corr.values.reshape(1, -1), annot=True, cmap='Reds')
plt.title('Kendall Correlation')

plt.tight_layout()
plt.show()

# %%
# Создаем массив для хранения результатов корреляции
corr_spearman = np.zeros((4, 4))
corr_pearson = np.zeros((4, 4))
corr_kendall = np.zeros((4, 4))

# Вычислим корреляцию Спирмена для всех сочетаний сигналов
for i in range(4):
    for j in range(4):
        query = data2.iloc[:, i].to_numpy()
        template = data1.iloc[:, j].to_numpy()

        corr_spearman[i, j] = stats.spearmanr(query, template).correlation # Корреляция Спирмена
        corr_pearson[i, j] = np.corrcoef(query, template)[0, 1]  # Корреляция Пирсона
        corr_kendall[i, j] = stats.kendalltau(query, template).correlation  # Корреляция Кендалла

# Визуализируем результаты с использованием тепловой карты
# Корреляция Спирмена
sb.heatmap(corr_spearman, annot=True, cmap='Reds')
plt.title("Spearman, Data1 and Data2")
plt.show()

# Корреляция Пирсона
sb.heatmap(corr_pearson, annot=True, cmap='Reds')
plt.title("Pearson, Data1 and Data2")
plt.show()

# Корреляция Кендалла
sb.heatmap(corr_kendall, annot=True, cmap='Reds')
plt.title("Kendall, Data1 and Data2")
plt.show()

# %% [markdown]
# Dynamic Time Warping (DTW) (алгоритм динамической временной деформации)
# ---
# DTW - это метод сравнения временных рядов, который учитывает различия во времени и позволяет вычислить сходство между временными рядами, даже если они имеют разные скорости или длины.

# %%
# Создание пустой матрицы для хранения результатов DTW
dtw_res = np.zeros((4, 4))

# Переберите все сочетания временных рядов
for i in range(4):
    for j in range(4):
        query = data1.iloc[:, i].to_numpy()
        template = data1.iloc[:, j].to_numpy()
        dtw_distance = dtw(query, template, keep_internals=True)
        dtw_res[i, j] = dtw_distance.normalizedDistance

# Визуализация результатов с использованием тепловой карты
sb.heatmap(dtw_res, annot=True, cmap="Reds")
plt.title("Signal DTW distances, Data")
plt.show()

# %%
# Создаем пустую матрицу для хранения результатов DTW между Data1 и Data2
dtw_res_data1_data2 = np.zeros((4, 4))

# Перебераем все сочетания временных рядов из Data1 и Data2
for i in range(4):
    for j in range(4):
        query_data1 = data1.iloc[:, i].to_numpy()
        template_data2 = data2.iloc[:, j].to_numpy()
        dtw_distance_data1_data2 = dtw(query_data1, template_data2, keep_internals=True)
        dtw_normalized_distance_data1_data2 = dtw_distance_data1_data2.normalizedDistance
        dtw_res_data1_data2[i, j] = dtw_normalized_distance_data1_data2

# Визуализация результатов DTW между Data1 и Data2 с использованием тепловой карты
plt.figure(figsize=(12, 4))
plt.subplot(121)
sb.heatmap(dtw_res_data1_data2, annot=True, cmap="Reds")
plt.title("Signal DTW distances, Data1 to Data2")

plt.show()

# %%
# Вычислим DTW расстояния для Data1 и Data2
dtw_res_data1_data2 = np.zeros((4, 4))

for i in range(4):
    for j in range(4):
        query_data1 = data1.iloc[:, i].to_numpy()
        template_data2 = data2.iloc[:, j].to_numpy()
        dtw_distance_data1_data2 = dtw(query_data1, template_data2, keep_internals=True)
        dtw_normalized_distance_data1_data2 = dtw_distance_data1_data2.normalizedDistance
        dtw_res_data1_data2[i, j] = dtw_normalized_distance_data1_data2

# Визуализируем DTW результаты между Data1 и Data2
plt.figure(figsize=(12, 4))
plt.subplot(121)
sb.heatmap(dtw_res_data1_data2, annot=True, cmap="Reds")
plt.title("Signal DTW distances, Data1 to Data2")
plt.show()

# Сравнение с корреляциями
# Корреляция Спирмена
plt.subplot(122)
sb.heatmap(corr_spearman, annot=True, cmap='Reds')
plt.title("Spearman Correlation, Data1 to Data2")
plt.show()

# Корреляция Пирсона
sb.heatmap(corr_pearson, annot=True, cmap='Reds')
plt.title("Pearson Correlation, Data1 to Data2")
plt.show()

# Корреляция Кендалла
sb.heatmap(corr_kendall, annot=True, cmap='Reds')
plt.title("Kendall Correlation, Data1 to Data2")
plt.show()

# %% [markdown]
# Спектральная плотность сигнала
# ---

# %%
# Параметры для вычисления спектральной плотности
fs = 1000  # Частота дискретизации (замените на актуальное значение)
nperseg = 256  # Длина сегмента
noverlap = 128  # Перекрытие сегментов

# Вычисление спектральной плотности для data1
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
for i in range(4):  # Перебор всех сигналов в data1
    f, Pxx_den = welch(data1.iloc[:, i].values, fs=fs, nperseg=nperseg, noverlap=noverlap)
    plt.semilogy(f, Pxx_den, label=f'Signal {i}')
plt.title('Спектральная плотность мощности для Data1')
plt.xlabel('Частота (Гц)')
plt.ylabel('Спектральная плотность')
plt.legend()

# Вычисление спектральной плотности для data2
plt.subplot(2, 1, 2)
for i in range(4):  # Перебор всех сигналов в data2
    f, Pxx_den = welch(data2.iloc[:, i].values, fs=fs, nperseg=nperseg, noverlap=noverlap)
    plt.semilogy(f, Pxx_den, label=f'Signal {i}')
plt.title('Спектральная плотность мощности для Data2')
plt.xlabel('Частота (Гц)')
plt.ylabel('Спектральная плотность')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Декомпозиция
# ---

# %%
# Выбераем один из сигналов для декомпозиции
signal_to_decompose = data1.iloc[:, 0]

# STL декомпозиция
result = sm.tsa.seasonal_decompose(signal_to_decompose, model='additive', period=24)

# Извлекаем тренд, сезонность и остатки
trend = result.trend
seasonal = result.seasonal
residual = result.resid

# Визуализируем результаты
plt.figure(figsize=(12, 8))
plt.subplot(4, 1, 1)
plt.plot(signal_to_decompose)
plt.title('Исходный сигнал')

plt.subplot(4, 1, 2)
plt.plot(trend)
plt.title('Тренд')

plt.subplot(4, 1, 3)
plt.plot(seasonal)
plt.title('Сезонность')

plt.subplot(4, 1, 4)
plt.plot(residual)
plt.title('Остатки')

plt.tight_layout()
plt.show()

# %%
# Выбераем один из сигналов для декомпозиции
signal_to_decompose = data2.iloc[:, 0]

# STL декомпозиция
result = sm.tsa.seasonal_decompose(signal_to_decompose, model='additive', period=24)
 
# Извлекаем тренд, сезонность и остатки
trend = result.trend
seasonal = result.seasonal
residual = result.resid

# Визуализируем результаты
plt.figure(figsize=(12, 8))
plt.subplot(4, 1, 1)
plt.plot(signal_to_decompose)
plt.title('Исходный сигнал')

plt.subplot(4, 1, 2)
plt.plot(trend)
plt.title('Тренд')

plt.subplot(4, 1, 3)
plt.plot(seasonal)
plt.title('Сезонность')

plt.subplot(4, 1, 4)
plt.plot(residual)
plt.title('Остатки')

plt.tight_layout()
plt.show()
